# %%
import gpt_index

# %%
from gpt_index import GPTSimpleVectorIndex, JSONReader

# %%
data = JSONReader().load_data('rawdata/raw.json')

# %%
index = GPTSimpleVectorIndex(data)
# Out:
# INFO:root:> [build_index_from_documents] Total LLM token usage: 0 tokens
# INFO:root:> [build_index_from_documents] Total embedding token usage: 210634 tokens

# %%
index.query("What carriers are available?")
# Out:
# INFO:root:> [query] Total LLM token usage: 3788 tokens
# INFO:root:> [query] Total embedding token usage: 5 tokens
# ...

# %%
data2 = JSONReader(levels_back=0).load_data('rawdata/raw.json')

# %%
index2 = GPTSimpleVectorIndex(data2)
# Out:
# INFO:root:> [build_index_from_documents] Total LLM token usage: 0 tokens
# INFO:root:> [build_index_from_documents] Total embedding token usage: 229902 tokens

# %%
index2.query("What carriers are available?")
# Out:
# INFO:root:> [query] Total LLM token usage: 3546 tokens
# INFO:root:> [query] Total embedding token usage: 5 tokens
# ...

# %%
data3 = JSONReader(levels_back=0, collapse_length=100).load_data('rawdata/raw.json')

# %%
index3 = GPTSimpleVectorIndex(data3)
# Out:
# INFO:root:> [build_index_from_documents] Total LLM token usage: 0 tokens
# INFO:root:> [build_index_from_documents] Total embedding token usage: 226901 tokens

# %%
data3
# Out:
# [Document(text='buildId 2023-02-22 fc5f219ad\ncontent additionalAttributes attributes condition categories ["smartphones", "smartwatches", "tablets", "computing", "carrierstores", "dynamic", "hubs"]\ncontent additionalAttributes attributes condition country us\ncontent additionalAttributes attributes values selectAllRelation_bk True\ncontent additionalAttributes attributes values addPCToPricing_delete True\ncontent additionalAttributes attributes values summaryView_bk True\ncontent additionalAttributes attributes values headerCTA_bk True\ncontent additionalAttributes attributes values showWhereToBuy_bk False\ncontent additionalAttributes attributes values excludeNonCarrierOffers_bk False\ncontent additionalAttributes attributes values donotExcludeEti_bk True\ncontent additionalAttributes attributes values isMultiTradeIn True\ncontent additionalAttributes attributes values defaultToPage1 False\ncontent additionalAttributes attributes values offerTitleWhenOnlyBundleExists Bundle Offer\
# ...

# %%
index3.query("What carriers are available?")
# Out:
# INFO:root:> [query] Total LLM token usage: 3414 tokens
# INFO:root:> [query] Total embedding token usage: 5 tokens
# ...

# %%
index.query("What colors are available?")
# Out:
# INFO:root:> [query] Total LLM token usage: 4649 tokens
# INFO:root:> [query] Total embedding token usage: 5 tokens
# ...

# %%
index2.query("What colors are available?")
# Out:
# INFO:root:> [query] Total LLM token usage: 4726 tokens
# INFO:root:> [query] Total embedding token usage: 5 tokens
# ...

# %%
index2.query("What storage capacities are available?")
# Out:
# INFO:root:> [query] Total LLM token usage: 3329 tokens
# INFO:root:> [query] Total embedding token usage: 6 tokens
# ...

# %%
index2.query("How many GB of storage do they have?")
# Out:
# INFO:root:> [query] Total LLM token usage: 3555 tokens
# INFO:root:> [query] Total embedding token usage: 9 tokens
# ...
