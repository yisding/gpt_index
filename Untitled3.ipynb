# %%
import gpt_index

# %%
# !pwd
# Out:
# /Users/yi/Code/jsongpt/gpt_index

# %%
from gpt_index import GPTSimpleVectorIndex, SimpleDirectoryReader

# %%
data = SimpleDirectoryReader('data').load_data()

# %%
data
# Out:
# [Document(text='{\n  "buildId": "2023-02-22 fc5f219ad",\n  "content": {\n    "additionalAttributes": {\n      "attributes": [\n        {\n          "condition": {\n            "categories": [\n              "smartphones",\n              "smartwatches",\n              "tablets",\n              "computing",\n              "carrierstores",\n              "dynamic",\n              "hubs"\n            ],\n            "country": "us"\n          },\n          "values": {\n            "selectAllRelation_bk": true,\n            "addPCToPricing_delete": true,\n            "summaryView_bk": true,\n            "headerCTA_bk": true,\n            "showWhereToBuy_bk": false,\n            "excludeNonCarrierOffers_bk": false,\n            "donotExcludeEti_bk": true,\n            "isMultiTradeIn": true,\n            "defaultToPage1": false,\n            "offerTitleWhenOnlyBundleExists": "Bundle Offer",\n            "skipPaymentForNonCarrierOffers": true,\n            "skipPayment": false,\n            "addCartStep": true,\n            "clearPremiumCare": false,\n            "skipPremiumCare": true,\n            "clearAddons": false,\n            "clearAddonsForNonEcert": false,\n            "clearAddonsForBogo": true,\n            "clearBogoAddonsForNonEcert": true,\n            "hideGallery": true,\n            "showPCinPage1": true,\n            "hideBackinPage1": true,\n            "priceChangeOnColor": true,\n            "priceWithTradein": true,\n            "template": "rainbowTemplate"\n          }\n        },\n        {\n          "condition": { "categories": ["carrierstores"], "country": "us" },\n          "values": {\n            "skipPaymentForNonCarrierOffers": true,\n            "disableAvailableWithUnlocked": true\n          }\n        },\n        {\n          "condition": { "familyType": ["galaxy-tab-s7"], "country": "us" },\n          "values": {\n            "summaryView_bk": true,\n            "headerCTA_bk": true,\n            "excludeNonCarrierOffers_bk": false,\n            "donotExcludeEti_bk": true,\n            "defaultToPage1": false,\n            "offerTitleWhenOnlyBundleExists": "Bundle Offer",\n            "skipPaymentForNonCarrierOffers": true,\n            "skipPayment": false,\n            "addCartStep": true,\n            "clearPremiumCare": false,\n            "skipPremiumCare": true,\n            "clearAddons": false,\n            "clearAddonsForNonEcert": false,\n            "clearAddonsForBogo": true,\n            "clearBogoAddonsForNonEcert": true,\n            "hideGallery": true,\n            "showPCinPage1": true,\n            "hideBackinPage1": true,\n            "hideEppFlowForReserve": true,\n            "hideWhereToBuyForReserve": true,\n            "hideRunningSummaryForReserve": true,\n            "showReserveForm": false,\n            "reserveFlow": false\n          }\n        },\n        {\n          "condition": {\n            "familyType": ["us-cellular", "redemption", "hub", "tv"],\n            "country": "us"\n          },\n          "values": {\n            "skipPaymentForNonCarrierOffers": true,\n            "skipPayment": false,\n            "addCartStep": true,\n            "clearPremiumCare": false,\n            "skipPremiumCare": true,\n            "clearAddons": false,\n            "clearAddonsForNonEcert": true,\n            "clearAddonsForBogo": true,\n            "clearBogoAddonsForNonEcert": true,\n            "hideGallery": true,\n            "showPCinPage1": true,\n            "hideBackinPage1": true\n          }\n        },\n        {\n          "condition": {\n            "familyType": ["galaxy-note20"],\n            "country": "us",\n            "queryParam": [{ "key": "offerCID", "value": "preorder" }]\n          },\n          "values": { "showWhereToBuy": false, "preOrderFlow": true }\n        },\n        {\n          "condition": {\n            "country": "us",\n            "familyType": [\n              "galaxy-s21",\n              "galaxy-s20",\n              "galaxy-note2 ...

# %%
index = GPTSimpleVectorIndex(data)
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 index = GPTSimpleVectorIndex(data)
#
# File ~/Code/jsongpt/gpt_index/gpt_index/indices/vector_store/vector_indices.py:83, in GPTSimpleVectorIndex.__init__(self, documents, index_struct, text_qa_template, llm_predictor, embed_model, simple_vector_store_data_dict, **kwargs)
#      78 """Init params."""
#      79 vector_store = SimpleVectorStore(
#      80     simple_vector_store_data_dict=simple_vector_store_data_dict
#      81 )
# ---> 83 super().__init__(
#      84     documents=documents,
#      85     index_struct=index_struct,
#      86     text_qa_template=text_qa_template,
#      87     llm_predictor=llm_predictor,
#      88     embed_model=embed_model,
#      89     vector_store=vector_store,
#      90     **kwargs,
#      91 )
#      93 # TODO: Temporary hack to also store embeddings in index_struct
#      94 embedding_dict = vector_store._data.embedding_dict
#
# File ~/Code/jsongpt/gpt_index/gpt_index/indices/vector_store/base.py:62, in GPTVectorStoreIndex.__init__(self, documents, index_struct, text_qa_template, llm_predictor, embed_model, vector_store, text_splitter, use_async, **kwargs)
#      60 self.text_qa_template = text_qa_template or DEFAULT_TEXT_QA_PROMPT
#      61 self._use_async = use_async
# ---> 62 super().__init__(
#      63     documents=documents,
#      64     index_struct=index_struct,
#      65     llm_predictor=llm_predictor,
#      66     embed_model=embed_model,
#      67     text_splitter=text_splitter,
#      68     **kwargs,
#      69 )
#
# File ~/Code/jsongpt/gpt_index/gpt_index/indices/base.py:81, in BaseGPTIndex.__init__(self, documents, index_struct, llm_predictor, embed_model, docstore, index_registry, prompt_helper, text_splitter, chunk_size_limit, include_extra_info)
#      78 if index_struct is not None and documents is not None:
#      79     raise ValueError("Only one of documents or index_struct can be provided.")
# ---> 81 self._llm_predictor = llm_predictor or LLMPredictor()
#      82 # NOTE: the embed_model isn't used in all indices
#      83 self._embed_model = embed_model or OpenAIEmbedding()
#
# File ~/Code/jsongpt/gpt_index/gpt_index/langchain_helpers/chain_wrapper.py:79, in LLMPredictor.__init__(self, llm, retry_on_throttling)
#      75 def __init__(
#      76     self, llm: Optional[BaseLLM] = None, retry_on_throttling: bool = True
#      77 ) -> None:
#      78     """Initialize params."""
# ---> 79     self._llm = llm or OpenAI(temperature=0, model_name="text-davinci-003")
#      80     self.retry_on_throttling = retry_on_throttling
#      81     self._total_tokens_used = 0
#
# File ~/opt/anaconda3/envs/dallemini/lib/python3.10/site-packages/pydantic/main.py:342, in pydantic.main.BaseModel.__init__()
#
# ValidationError: 1 validation error for OpenAI
# __root__
#   Did not find openai_api_key, please add an environment variable `OPENAI_API_KEY` which contains it, or pass  `openai_api_key` as a named parameter. (type=value_error)

# %%
os.environ['OPENAI_API_KEY'] = ""
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 os.environ['OPENAI_API_KEY'] = "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"
#
# NameError: name 'os' is not defined

# %%
import os

# %%
os.environ['OPENAI_API_KEY'] = ""

# %%
index = GPTSimpleVectorIndex(data)
# Out:
# INFO:root:> [build_index_from_documents] Total LLM token usage: 0 tokens
# INFO:root:> [build_index_from_documents] Total embedding token usage: 330681 tokens

# %%
index.query("What colors is the S23 Ultra in?")
# Out:
# INFO:root:> [query] Total LLM token usage: 3859 tokens
# INFO:root:> [query] Total embedding token usage: 9 tokens
# Response(response='\nThe Samsung Galaxy S23 Ultra is available in Cosmic Gray, Phantom Black, and Phantom Silver. Carrier specific smartphones will not be activated on a network when purchased on Samsung.com, and all sales are subject to the full Terms of Sale.', source_nodes=[SourceNode(source_text='notice. </div> <span class=\'read-more-link\'>Show More</span> <br />\\n <br />\\n <div class=\'terms-section\'>  <sup>1</sup>QLED screens can produce 100% Color Volume in the DCI-P3 color space, the format for most cinema screens and HDR movies for television. </div> <br />\\n <br />\\n <div class=\'terms-section\'>  <sup>2</sup>Universal Stylus (USI) pen is a separate accessory, not included. Find out more about the universal stylus initiative at <a style=\'color: #0077c8;\' href=\'https://universalstylus.org\' target=\'_blank\'>universalstylus.org</a>. </div> <br />\\n <br />\\n <div class=\'terms-section\'>  <sup>3</sup>Chromebook software updates generally arrive every six weeks but are occasionally delayed to ensure optimal user experience upon rollout. </div> <br />\\n <br />\\n <div class=\'terms-section\'>  <sup>4</sup>Use of this feature requires you to have an agreement with a UEM provider. </div> <br />\\n <br />\\n <div class=\'terms-section\'>  <sup>5</sup>Chrome Enterprise license is available for an additional fee. </div> <br />\\n <br />\\n</div>"\n          },\n          "chromebook2": {\n            "generalTerms": "<div> <div class=\'terms-section\'>  © 2021 Samsung Electronics America, Inc. All rights reserved. Samsung is a registered trademark of Samsung Electronics Co., Ltd. All products, logos and brand names are trademarks or registered trademarks of their respective companies. Screen images simulated. </div> <span class=\'read-more-link\'>Show More</span> <br />\\n <br />\\n <div class=\'terms-section\'>   <strong>Price, Promotion, Processing: </strong> Pricing, delivery date and other errors may be withdrawn or revised and/or your order may be cancelled at any time, without prior notice, before we have both (a) shipped or provided access to your product or service, and (b) received your payment for the product or service. All sales on <a href=\\"https://samsung.com\\" target=\\"_blank\\">Samsung.com</a> are subject to the full <a href=\\"https://www.samsung.com/us/business/shop/terms-and-conditions/\\" tar>Terms of Sale</a>. Samsung is not responsible for any errors, omissions or misdirected or lost orders, or orders which may be delayed. Samsung reserves the right to modify pricing and modify or cancel promotions at any time, without prior notice. </div> <span class=\'read-more-link\'>Show More</span> <br />\\n <br />\\n <div class=\'terms-section\'>  <sup>1</sup>QLED screens can produce 100% Color Volume in the DCI-P3 color space, the format for most cinema screens and HDR movies for television. </div> <br />\\n <br />\\n <div class=\'terms-section\'>  <sup>2</sup>Universal Stylus (USI) pen is a separate accessory, not included. Find out more about the universal stylus initiative at <a style=\'color: #0077c8;\' href=\'https://universalstylus.org\' target=\'_blank\'>universalstylus.org</a>. </div> <br />\\n <br />\\n <div class=\'terms-section\'>  <sup>3</sup>Chromebook software updates generally arrive every six weeks but are occasionally delayed to ensure optimal user experience upon rollout. </div> <br />\\n <br />\\n <div class=\'terms-section\'>  <sup>4</sup>Use of this feature requires you to have an agreement with a UEM provider. </div> <br />\\n <br />\\n <div class=\'terms-section\'>  <sup>5</sup>Chrome Enterprise license is available for an additional fee. </div> <br />\\n <br />\\n</div>"\n          },\n          "galaxy-xcover": {\n            "generalTerms": "<div> <div class=\'terms-section\'>  © 2021 Samsung Electronics America, Inc. All rights reserved. Samsung is a registered trademark of Samsung Electronics Co., Ltd. All products, logos and brand names are trademarks or registered trad ...

# %%
response = index.query("What colors is the S23 Ultra in?")
# Out:
# INFO:root:> [query] Total LLM token usage: 3859 tokens
# INFO:root:> [query] Total embedding token usage: 9 tokens

# %%
str(response)
# Out:
# '\nThe Samsung Galaxy S23 Ultra is available in Cosmic Gray, Phantom Black, and Phantom Silver. Carrier specific smartphones will not be activated on a network when purchased on Samsung.com, and all sales are subject to the full Terms of Sale.'

# %%
response.source_nodes[0].source_text
# Out:
# 'notice. </div> <span class=\'read-more-link\'>Show More</span> <br />\\n <br />\\n <div class=\'terms-section\'>  <sup>1</sup>QLED screens can produce 100% Color Volume in the DCI-P3 color space, the format for most cinema screens and HDR movies for television. </div> <br />\\n <br />\\n <div class=\'terms-section\'>  <sup>2</sup>Universal Stylus (USI) pen is a separate accessory, not included. Find out more about the universal stylus initiative at <a style=\'color: #0077c8;\' href=\'https://universalstylus.org\' target=\'_blank\'>universalstylus.org</a>. </div> <br />\\n <br />\\n <div class=\'terms-section\'>  <sup>3</sup>Chromebook software updates generally arrive every six weeks but are occasionally delayed to ensure optimal user experience upon rollout. </div> <br />\\n <br />\\n <div class=\'terms-section\'>  <sup>4</sup>Use of this feature requires you to have an agreement with a UEM provider. </div> <br />\\n <br />\\n <div class=\'terms-section\'>  <sup>5</sup>Chrome Enterprise license is available for an additional fee. </div> <br />\\n <br />\\n</div>"\n          },\n          "chromebook2": {\n            "generalTerms": "<div> <div class=\'terms-section\'>  © 2021 Samsung Electronics America, Inc. All rights reserved. Samsung is a registered trademark of Samsung Electronics Co., Ltd. All products, logos and brand names are trademarks or registered trademarks of their respective companies. Screen images simulated. </div> <span class=\'read-more-link\'>Show More</span> <br />\\n <br />\\n <div class=\'terms-section\'>   <strong>Price, Promotion, Processing: </strong> Pricing, delivery date and other errors may be withdrawn or revised and/or your order may be cancelled at any time, without prior notice, before we have both (a) shipped or provided access to your product or service, and (b) received your payment for the product or service. All sales on <a href=\\"https://samsung.com\\" target=\\"_blank\\">Samsung.com</a> are subject to the full <a href=\\"https://www.samsung.com/us/business/shop/terms-and-conditions/\\" tar>Terms of Sale</a>. Samsung is not responsible for any errors, omissions or misdirected or lost orders, or orders which may be delayed. Samsung reserves the right to modify pricing and modify or cancel promotions at any time, without prior notice. </div> <span class=\'read-more-link\'>Show More</span> <br />\\n <br />\\n <div class=\'terms-section\'>  <sup>1</sup>QLED screens can produce 100% Color Volume in the DCI-P3 color space, the format for most cinema screens and HDR movies for television. </div> <br />\\n <br />\\n <div class=\'terms-section\'>  <sup>2</sup>Universal Stylus (USI) pen is a separate accessory, not included. Find out more about the universal stylus initiative at <a style=\'color: #0077c8;\' href=\'https://universalstylus.org\' target=\'_blank\'>universalstylus.org</a>. </div> <br />\\n <br />\\n <div class=\'terms-section\'>  <sup>3</sup>Chromebook software updates generally arrive every six weeks but are occasionally delayed to ensure optimal user experience upon rollout. </div> <br />\\n <br />\\n <div class=\'terms-section\'>  <sup>4</sup>Use of this feature requires you to have an agreement with a UEM provider. </div> <br />\\n <br />\\n <div class=\'terms-section\'>  <sup>5</sup>Chrome Enterprise license is available for an additional fee. </div> <br />\\n <br />\\n</div>"\n          },\n          "galaxy-xcover": {\n            "generalTerms": "<div> <div class=\'terms-section\'>  © 2021 Samsung Electronics America, Inc. All rights reserved. Samsung is a registered trademark of Samsung Electronics Co., Ltd. All products, logos and brand names are trademarks or registered trademarks of their respective companies. Screen images simulated. </div> <span class=\'read-more-link\'>Show More</span> <br />\\n <br />\\n <div class=\'terms-section\'>   <strong>Price, Promotion, Processing: </strong> Pricing, delivery date and other errors may be withdrawn or revised and/or your ord ...

# %%
response.query("Which carriers is the S23 Ultra offered on?")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 response.query("Which carriers is the S23 Ultra offered on?")
#
# AttributeError: 'Response' object has no attribute 'query'

# %%
response2 = index.query("Which carriers is the S23 Ultra offered on?")
# Out:
# INFO:root:> [query] Total LLM token usage: 3915 tokens
# INFO:root:> [query] Total embedding token usage: 10 tokens

# %%
str(response2)
# Out:
# '\n\nThe Samsung Galaxy S23 Ultra is offered on all major carriers, including Verizon, AT&T, T-Mobile, and Sprint. Additionally, customers who pre-order or purchase the device from Samsung.com or the Shop Samsung app may be eligible to receive a Spotify 6-month trial with their purchase.'

# %%
rawdata = SimpleDirectoryReader('rawdata').load_data()

# %%
rawindex = GPTSimpleVectorIndex(rawdata)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# File ~/opt/anaconda3/envs/dallemini/lib/python3.10/site-packages/tenacity/__init__.py:409, in Retrying.__call__(self, fn, *args, **kwargs)
#     408 try:
# --> 409     result = fn(*args, **kwargs)
#     410 except BaseException:  # noqa: B902
#
# File ~/Code/jsongpt/gpt_index/gpt_index/embeddings/openai.py:142, in get_embeddings(list_of_text, engine)
#     133 """Get embeddings.
#     134
#     135 NOTE: Copied from OpenAI's embedding utils:
#    (...)
#     140
#     141 """
# --> 142 assert len(list_of_text) <= 2048, "The batch size should not be larger than 2048."
#     144 # replace newlines, which can negatively affect performance.
#
# AssertionError: The batch size should not be larger than 2048.
#
# The above exception was the direct cause of the following exception:
#
# RetryError                                Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 rawindex = GPTSimpleVectorIndex(rawdata)
#
# File ~/Code/jsongpt/gpt_index/gpt_index/indices/vector_store/vector_indices.py:83, in GPTSimpleVectorIndex.__init__(self, documents, index_struct, text_qa_template, llm_predictor, embed_model, simple_vector_store_data_dict, **kwargs)
#      78 """Init params."""
#      79 vector_store = SimpleVectorStore(
#      80     simple_vector_store_data_dict=simple_vector_store_data_dict
#      81 )
# ---> 83 super().__init__(
#      84     documents=documents,
#      85     index_struct=index_struct,
#      86     text_qa_template=text_qa_template,
#      87     llm_predictor=llm_predictor,
#      88     embed_model=embed_model,
#      89     vector_store=vector_store,
#      90     **kwargs,
#      91 )
#      93 # TODO: Temporary hack to also store embeddings in index_struct
#      94 embedding_dict = vector_store._data.embedding_dict
#
# File ~/Code/jsongpt/gpt_index/gpt_index/indices/vector_store/base.py:62, in GPTVectorStoreIndex.__init__(self, documents, index_struct, text_qa_template, llm_predictor, embed_model, vector_store, text_splitter, use_async, **kwargs)
#      60 self.text_qa_template = text_qa_template or DEFAULT_TEXT_QA_PROMPT
#      61 self._use_async = use_async
# ---> 62 super().__init__(
#      63     documents=documents,
#      64     index_struct=index_struct,
#      65     llm_predictor=llm_predictor,
#      66     embed_model=embed_model,
#      67     text_splitter=text_splitter,
#      68     **kwargs,
#      69 )
#
# File ~/Code/jsongpt/gpt_index/gpt_index/indices/base.py:109, in BaseGPTIndex.__init__(self, documents, index_struct, llm_predictor, embed_model, docstore, index_registry, prompt_helper, text_splitter, chunk_size_limit, include_extra_info)
#     107     self._validate_documents(documents)
#     108     # TODO: introduce document store outside __init__ function
# --> 109     self._index_struct = self.build_index_from_documents(documents)
#     110 # update index registry and docstore with index_struct
#     111 self._update_index_registry_and_docstore()
#
# File ~/Code/jsongpt/gpt_index/gpt_index/token_counter/token_counter.py:55, in llm_token_counter.<locals>.wrap.<locals>.wrapped_llm_predict(_self, *args, **kwargs)
#      52 start_token_ct = llm_predictor.total_tokens_used
#      53 start_embed_token_ct = embed_model.total_tokens_used
# ---> 55 f_return_val = f(_self, *args, **kwargs)
#      57 net_tokens = llm_predictor.total_tokens_used - start_token_ct
#      58 llm_predictor.last_token_usage = net_tokens
#
# File ~/Code/jsongpt/gpt_index/gpt_index/indices/base.py:278, in BaseGPTIndex.build_index_from_documents(self, documents)
#     275 @llm_token_counter("build_index_from_documents")
#     276 def build_index_from_documents(self, documents: Sequence[BaseDocument]) -> IS:
#     277     """Build the index from documents."""
# --> 278     return self._build_index_from_documents(documents)
#
# File ~/Code/jsongpt/gpt_index/gpt_index/indices/vector_store/base.py:205, in GPTVectorStoreIndex._build_index_from_documents(self, documents)
#     203 else:
#     204     for d in documents:
# --> 205         self._add_document_to_index(index_struct, d)
#     206 return index_struct
#
# File ~/Code/jsongpt/gpt_index/gpt_index/indices/vector_store/base.py:181, in GPTVectorStoreIndex._add_document_to_index(self, index_struct, document)
#     179 """Add document to index."""
#     180 nodes = self._get_nodes_from_document(document)
# --> 181 embedding_results = self._get_node_embedding_results(
#     182     nodes, set(), document.get_doc_id()
#     183 )
#     185 new_ids = self._vector_store.add(embedding_results)
#     187 # if the vector store doesn't store text, we need to add the nodes to the
#     188 # index struct
#
# File ~/Code/jsongpt/gpt_index/gpt_index/indices/vector_store/base.py:101, in GPTVectorStoreIndex._get_node_embedding_results(self, nodes, existing_node_ids, doc_id)
#      98     id_to_node_map[new_id] = n
#     100 # call embedding model to get embeddings
# --> 101 result_ids, result_embeddings = self._embed_model.get_queued_text_embeddings()
#     102 for new_id, text_embedding in zip(result_ids, result_embeddings):
#     103     id_to_embed_map[new_id] = text_embedding
#
# File ~/Code/jsongpt/gpt_index/gpt_index/embeddings/base.py:151, in BaseEmbedding.get_queued_text_embeddings(self)
#     149 cur_batch_ids = [text_id for text_id, _ in cur_batch]
#     150 cur_batch_texts = [text for _, text in cur_batch]
# --> 151 embeddings = self._get_text_embeddings(cur_batch_texts)
#     152 result_ids.extend(cur_batch_ids)
#     153 result_embeddings.extend(embeddings)
#
# File ~/Code/jsongpt/gpt_index/gpt_index/embeddings/openai.py:260, in OpenAIEmbedding._get_text_embeddings(self, texts)
#     258         raise ValueError(f"Invalid mode, model combination: {key}")
#     259     engine = _TEXT_MODE_MODEL_DICT[key]
# --> 260 embeddings = get_embeddings(texts, engine=engine)
#     261 return embeddings
#
# File ~/opt/anaconda3/envs/dallemini/lib/python3.10/site-packages/tenacity/__init__.py:326, in BaseRetrying.wraps.<locals>.wrapped_f(*args, **kw)
#     324 @functools.wraps(f)
#     325 def wrapped_f(*args: t.Any, **kw: t.Any) -> t.Any:
# --> 326     return self(f, *args, **kw)
#
# File ~/opt/anaconda3/envs/dallemini/lib/python3.10/site-packages/tenacity/__init__.py:406, in Retrying.__call__(self, fn, *args, **kwargs)
#     404 retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     405 while True:
# --> 406     do = self.iter(retry_state=retry_state)
#     407     if isinstance(do, DoAttempt):
#     408         try:
#
# File ~/opt/anaconda3/envs/dallemini/lib/python3.10/site-packages/tenacity/__init__.py:363, in BaseRetrying.iter(self, retry_state)
#     361     if self.reraise:
#     362         raise retry_exc.reraise()
# --> 363     raise retry_exc from fut.exception()
#     365 if self.wait:
#     366     sleep = self.wait(retry_state=retry_state)
#
# RetryError: RetryError[<Future at 0x7fdbeb4991e0 state=finished raised AssertionError>]

# %%
rawdata = SimpleDirectoryReader('rawdata').load_data()

# %%
rawindex = GPTSimpleVectorIndex(rawdata)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# File ~/opt/anaconda3/envs/dallemini/lib/python3.10/site-packages/tenacity/__init__.py:409, in Retrying.__call__(self, fn, *args, **kwargs)
#     408 try:
# --> 409     result = fn(*args, **kwargs)
#     410 except BaseException:  # noqa: B902
#
# File ~/Code/jsongpt/gpt_index/gpt_index/embeddings/openai.py:142, in get_embeddings(list_of_text, engine)
#     133 """Get embeddings.
#     134
#     135 NOTE: Copied from OpenAI's embedding utils:
#    (...)
#     140
#     141 """
# --> 142 assert len(list_of_text) <= 2048, "The batch size should not be larger than 2048."
#     144 # replace newlines, which can negatively affect performance.
#
# AssertionError: The batch size should not be larger than 2048.
#
# The above exception was the direct cause of the following exception:
#
# RetryError                                Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 rawindex = GPTSimpleVectorIndex(rawdata)
#
# File ~/Code/jsongpt/gpt_index/gpt_index/indices/vector_store/vector_indices.py:83, in GPTSimpleVectorIndex.__init__(self, documents, index_struct, text_qa_template, llm_predictor, embed_model, simple_vector_store_data_dict, **kwargs)
#      78 """Init params."""
#      79 vector_store = SimpleVectorStore(
#      80     simple_vector_store_data_dict=simple_vector_store_data_dict
#      81 )
# ---> 83 super().__init__(
#      84     documents=documents,
#      85     index_struct=index_struct,
#      86     text_qa_template=text_qa_template,
#      87     llm_predictor=llm_predictor,
#      88     embed_model=embed_model,
#      89     vector_store=vector_store,
#      90     **kwargs,
#      91 )
#      93 # TODO: Temporary hack to also store embeddings in index_struct
#      94 embedding_dict = vector_store._data.embedding_dict
#
# File ~/Code/jsongpt/gpt_index/gpt_index/indices/vector_store/base.py:62, in GPTVectorStoreIndex.__init__(self, documents, index_struct, text_qa_template, llm_predictor, embed_model, vector_store, text_splitter, use_async, **kwargs)
#      60 self.text_qa_template = text_qa_template or DEFAULT_TEXT_QA_PROMPT
#      61 self._use_async = use_async
# ---> 62 super().__init__(
#      63     documents=documents,
#      64     index_struct=index_struct,
#      65     llm_predictor=llm_predictor,
#      66     embed_model=embed_model,
#      67     text_splitter=text_splitter,
#      68     **kwargs,
#      69 )
#
# File ~/Code/jsongpt/gpt_index/gpt_index/indices/base.py:109, in BaseGPTIndex.__init__(self, documents, index_struct, llm_predictor, embed_model, docstore, index_registry, prompt_helper, text_splitter, chunk_size_limit, include_extra_info)
#     107     self._validate_documents(documents)
#     108     # TODO: introduce document store outside __init__ function
# --> 109     self._index_struct = self.build_index_from_documents(documents)
#     110 # update index registry and docstore with index_struct
#     111 self._update_index_registry_and_docstore()
#
# File ~/Code/jsongpt/gpt_index/gpt_index/token_counter/token_counter.py:55, in llm_token_counter.<locals>.wrap.<locals>.wrapped_llm_predict(_self, *args, **kwargs)
#      52 start_token_ct = llm_predictor.total_tokens_used
#      53 start_embed_token_ct = embed_model.total_tokens_used
# ---> 55 f_return_val = f(_self, *args, **kwargs)
#      57 net_tokens = llm_predictor.total_tokens_used - start_token_ct
#      58 llm_predictor.last_token_usage = net_tokens
#
# File ~/Code/jsongpt/gpt_index/gpt_index/indices/base.py:278, in BaseGPTIndex.build_index_from_documents(self, documents)
#     275 @llm_token_counter("build_index_from_documents")
#     276 def build_index_from_documents(self, documents: Sequence[BaseDocument]) -> IS:
#     277     """Build the index from documents."""
# --> 278     return self._build_index_from_documents(documents)
#
# File ~/Code/jsongpt/gpt_index/gpt_index/indices/vector_store/base.py:205, in GPTVectorStoreIndex._build_index_from_documents(self, documents)
#     203 else:
#     204     for d in documents:
# --> 205         self._add_document_to_index(index_struct, d)
#     206 return index_struct
#
# File ~/Code/jsongpt/gpt_index/gpt_index/indices/vector_store/base.py:181, in GPTVectorStoreIndex._add_document_to_index(self, index_struct, document)
#     179 """Add document to index."""
#     180 nodes = self._get_nodes_from_document(document)
# --> 181 embedding_results = self._get_node_embedding_results(
#     182     nodes, set(), document.get_doc_id()
#     183 )
#     185 new_ids = self._vector_store.add(embedding_results)
#     187 # if the vector store doesn't store text, we need to add the nodes to the
#     188 # index struct
#
# File ~/Code/jsongpt/gpt_index/gpt_index/indices/vector_store/base.py:101, in GPTVectorStoreIndex._get_node_embedding_results(self, nodes, existing_node_ids, doc_id)
#      98     id_to_node_map[new_id] = n
#     100 # call embedding model to get embeddings
# --> 101 result_ids, result_embeddings = self._embed_model.get_queued_text_embeddings()
#     102 for new_id, text_embedding in zip(result_ids, result_embeddings):
#     103     id_to_embed_map[new_id] = text_embedding
#
# File ~/Code/jsongpt/gpt_index/gpt_index/embeddings/base.py:151, in BaseEmbedding.get_queued_text_embeddings(self)
#     149 cur_batch_ids = [text_id for text_id, _ in cur_batch]
#     150 cur_batch_texts = [text for _, text in cur_batch]
# --> 151 embeddings = self._get_text_embeddings(cur_batch_texts)
#     152 result_ids.extend(cur_batch_ids)
#     153 result_embeddings.extend(embeddings)
#
# File ~/Code/jsongpt/gpt_index/gpt_index/embeddings/openai.py:260, in OpenAIEmbedding._get_text_embeddings(self, texts)
#     258         raise ValueError(f"Invalid mode, model combination: {key}")
#     259     engine = _TEXT_MODE_MODEL_DICT[key]
# --> 260 embeddings = get_embeddings(texts, engine=engine)
#     261 return embeddings
#
# File ~/opt/anaconda3/envs/dallemini/lib/python3.10/site-packages/tenacity/__init__.py:326, in BaseRetrying.wraps.<locals>.wrapped_f(*args, **kw)
#     324 @functools.wraps(f)
#     325 def wrapped_f(*args: t.Any, **kw: t.Any) -> t.Any:
# --> 326     return self(f, *args, **kw)
#
# File ~/opt/anaconda3/envs/dallemini/lib/python3.10/site-packages/tenacity/__init__.py:406, in Retrying.__call__(self, fn, *args, **kwargs)
#     404 retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     405 while True:
# --> 406     do = self.iter(retry_state=retry_state)
#     407     if isinstance(do, DoAttempt):
#     408         try:
#
# File ~/opt/anaconda3/envs/dallemini/lib/python3.10/site-packages/tenacity/__init__.py:363, in BaseRetrying.iter(self, retry_state)
#     361     if self.reraise:
#     362         raise retry_exc.reraise()
# --> 363     raise retry_exc from fut.exception()
#     365 if self.wait:
#     366     sleep = self.wait(retry_state=retry_state)
#
# RetryError: RetryError[<Future at 0x7fdb782e3340 state=finished raised AssertionError>]

# %%
rawindex.query("Which carriers is the S23 Ultra offered on?")

# %%
rawindex.query("Which carriers is the S23 Ultra offered on?")
# Out:
# INFO:root:> [query] Total LLM token usage: 3915 tokens
# INFO:root:> [query] Total embedding token usage: 10 tokens
# Response(response='\n\nThe Samsung Galaxy S23 Ultra is offered on all major carriers, including Verizon, AT&T, T-Mobile, and Sprint. Additionally, customers who pre-order or purchase the device from Samsung.com or the Shop Samsung app may be eligible to receive a Spotify 6-month trial with their purchase.', source_nodes=[SourceNode(source_text='unless specifically provided for in the terms and conditions of such offers. Additional terms, including terms that govern the resolution of disputes, apply. Click here to <a style=\'color: #0077c8;\' data-url=\'https://www.samsung.com/us/trade-in/terms-and-conditions/\' href=\'https://www.samsung.com/us/trade-in/terms-and-conditions/ \'  target=\'_blank\'>learn more</a></p>\\n </div> <span class=\'read-more-link\'>Show More</span> <br /> <br /> <div class=\'terms-section\'> <sup>φ</sup>Limited time only, while supplies last, exclusively on Samsung.com and the Shop Samsung App (excluding in-person Samsung Studios transactions made using the App). You must opt-in to the Samsung Upgrade Program, apply and be approved for a financing account (“Financing Account”) under the Samsung Financing Program, make an initial purchase of an eligible Samsung Galaxy device (“Initial Device”) on a 24 month payment plan using your Financing Account on standard financing terms or a separate required financing offer.\\n </div> <span class=\'read-more-link\'>Show More</span> <br /><br />\\n <div class=\'terms-section\'> *Please note that only your S20 will be eligible for the Upgrade Program.  The other items you selected will not be eligible for Upgrade and will be subject to 24 month Samsung Financing. </div> <br/> \\n <div class=\'terms-section\'>Verizon customers only: The Galaxy S20 5G is not compatible with Verizon’s current wideband 5G network but will work with Verizon’s 4G LTE service. Please consider the Verizon-compatible S20+ 5G or S20 Ultra 5G.</div></div> @disclaimer@ <br />\\n"\n        },\n        "galaxy-s20-fe": {\n          "generalTerms": "<div class=\'terms-section\'><sup>⊕</sup><strong> 0% APR for 24, 36 and 48 Months with Equal Payments:</strong> Available on purchases of select products charged to a Samsung Financing account. Minimum purchase: $49 for 24 months on phones, mobile accessories, tablets, PCs, and wearables; $299.99 for 36 months on phones, mobile accessories, tablets, PCs and wearables; $499.99 for 36 months on TVs; $649.99 for 48 months on PCs and $999.99 for 48 months on TVs. 0% APR from date of eligible purchase until paid in full. Monthly payment equals the eligible purchase amount multiplied by a repayment factor and rounded to the nearest penny (repayment factors: .04167 for 24 month, .02778 for 36 month, .02083 for 48 month). Last payment may vary due to rounding. Total amount of payments will not exceed eligible purchase amount. Other transactions and fees affect overall minimum payment amount. Advertised payment amount excludes taxes, delivery or other charges. Limited time offer. Regular account terms apply to non-promo purchases. Minimum interest charge: $1. Standard Purchase APR: 29.99%. Prior purchases excluded. Account must be in good standing. Subject to credit approval. Samsung Financing account issued by TD Bank, N.A\\n </div><span class=\'read-more-link\'>Show More</span> <br />\\n <br />\\n<div class=\'terms-section\'><sup>†</sup><strong> No Interest if Paid in Full within 6, 12, 18 or 24 Months:</strong> Available on purchases of select products charged to a Samsung Financing account. On purchases of $49 to $499.99 for 6-month and $500 or more for 12-month, 18-month, or 24-month. To avoid interest, you must pay the full promo balance before the promo period ends. If you do not, you will be charged interest from the purchase date at the standard Purchase APR. After the promo period ends, the standard APR also applies to the remaining balance and the charged interest. You are required to make minimum payments, but minimum payments will not pay off the b ...

# %%
questions = ["Which carriers is the S23 Ultra offered on?", "Which carriers is the S23 Ultra offered on?", "Which capacities are available in the S23 Ultra?"]

# %%
rawindex.query("Which capacities are available in the S23 Ultra?")
# Out:
# INFO:root:> [query] Total LLM token usage: 3856 tokens
# INFO:root:> [query] Total embedding token usage: 10 tokens
# Response(response='\nThe Samsung Galaxy S23 Ultra is not available yet, so the capacities are not known. However, once it is available, customers can purchase it on Samsung.com and will be subject to the full Terms of Sale.', source_nodes=[SourceNode(source_text='notice. </div> <span class=\'read-more-link\'>Show More</span> <br />\\n <br />\\n <div class=\'terms-section\'>  <sup>1</sup>QLED screens can produce 100% Color Volume in the DCI-P3 color space, the format for most cinema screens and HDR movies for television. </div> <br />\\n <br />\\n <div class=\'terms-section\'>  <sup>2</sup>Universal Stylus (USI) pen is a separate accessory, not included. Find out more about the universal stylus initiative at <a style=\'color: #0077c8;\' href=\'https://universalstylus.org\' target=\'_blank\'>universalstylus.org</a>. </div> <br />\\n <br />\\n <div class=\'terms-section\'>  <sup>3</sup>Chromebook software updates generally arrive every six weeks but are occasionally delayed to ensure optimal user experience upon rollout. </div> <br />\\n <br />\\n <div class=\'terms-section\'>  <sup>4</sup>Use of this feature requires you to have an agreement with a UEM provider. </div> <br />\\n <br />\\n <div class=\'terms-section\'>  <sup>5</sup>Chrome Enterprise license is available for an additional fee. </div> <br />\\n <br />\\n</div>"\n          },\n          "chromebook2": {\n            "generalTerms": "<div> <div class=\'terms-section\'>  © 2021 Samsung Electronics America, Inc. All rights reserved. Samsung is a registered trademark of Samsung Electronics Co., Ltd. All products, logos and brand names are trademarks or registered trademarks of their respective companies. Screen images simulated. </div> <span class=\'read-more-link\'>Show More</span> <br />\\n <br />\\n <div class=\'terms-section\'>   <strong>Price, Promotion, Processing: </strong> Pricing, delivery date and other errors may be withdrawn or revised and/or your order may be cancelled at any time, without prior notice, before we have both (a) shipped or provided access to your product or service, and (b) received your payment for the product or service. All sales on <a href=\\"https://samsung.com\\" target=\\"_blank\\">Samsung.com</a> are subject to the full <a href=\\"https://www.samsung.com/us/business/shop/terms-and-conditions/\\" tar>Terms of Sale</a>. Samsung is not responsible for any errors, omissions or misdirected or lost orders, or orders which may be delayed. Samsung reserves the right to modify pricing and modify or cancel promotions at any time, without prior notice. </div> <span class=\'read-more-link\'>Show More</span> <br />\\n <br />\\n <div class=\'terms-section\'>  <sup>1</sup>QLED screens can produce 100% Color Volume in the DCI-P3 color space, the format for most cinema screens and HDR movies for television. </div> <br />\\n <br />\\n <div class=\'terms-section\'>  <sup>2</sup>Universal Stylus (USI) pen is a separate accessory, not included. Find out more about the universal stylus initiative at <a style=\'color: #0077c8;\' href=\'https://universalstylus.org\' target=\'_blank\'>universalstylus.org</a>. </div> <br />\\n <br />\\n <div class=\'terms-section\'>  <sup>3</sup>Chromebook software updates generally arrive every six weeks but are occasionally delayed to ensure optimal user experience upon rollout. </div> <br />\\n <br />\\n <div class=\'terms-section\'>  <sup>4</sup>Use of this feature requires you to have an agreement with a UEM provider. </div> <br />\\n <br />\\n <div class=\'terms-section\'>  <sup>5</sup>Chrome Enterprise license is available for an additional fee. </div> <br />\\n <br />\\n</div>"\n          },\n          "galaxy-xcover": {\n            "generalTerms": "<div> <div class=\'terms-section\'>  © 2021 Samsung Electronics America, Inc. All rights reserved. Samsung is a registered trademark of Samsung Electronics Co., Ltd. All products, logos and brand names are trademarks or registered trademarks of their respective companies.  ...

# %%
index.query("Which capacities are available in the S23 Ultra?")
# Out:
# INFO:root:> [query] Total LLM token usage: 3891 tokens
# INFO:root:> [query] Total embedding token usage: 10 tokens
# Response(response='\nThe Samsung Galaxy S23 Ultra is not available yet, so the capacities are not known. However, once it is available, customers can purchase it on Samsung.com, subject to the full Terms of Sale. Samsung reserves the right to modify pricing and modify or cancel promotions at any time, without prior notice. Carrier specific smartphones will not be activated on a network when purchased on Samsung.com.', source_nodes=[SourceNode(source_text='notice. </div> <span class=\'read-more-link\'>Show More</span> <br />\\n <br />\\n <div class=\'terms-section\'>  <sup>1</sup>QLED screens can produce 100% Color Volume in the DCI-P3 color space, the format for most cinema screens and HDR movies for television. </div> <br />\\n <br />\\n <div class=\'terms-section\'>  <sup>2</sup>Universal Stylus (USI) pen is a separate accessory, not included. Find out more about the universal stylus initiative at <a style=\'color: #0077c8;\' href=\'https://universalstylus.org\' target=\'_blank\'>universalstylus.org</a>. </div> <br />\\n <br />\\n <div class=\'terms-section\'>  <sup>3</sup>Chromebook software updates generally arrive every six weeks but are occasionally delayed to ensure optimal user experience upon rollout. </div> <br />\\n <br />\\n <div class=\'terms-section\'>  <sup>4</sup>Use of this feature requires you to have an agreement with a UEM provider. </div> <br />\\n <br />\\n <div class=\'terms-section\'>  <sup>5</sup>Chrome Enterprise license is available for an additional fee. </div> <br />\\n <br />\\n</div>"\n          },\n          "chromebook2": {\n            "generalTerms": "<div> <div class=\'terms-section\'>  © 2021 Samsung Electronics America, Inc. All rights reserved. Samsung is a registered trademark of Samsung Electronics Co., Ltd. All products, logos and brand names are trademarks or registered trademarks of their respective companies. Screen images simulated. </div> <span class=\'read-more-link\'>Show More</span> <br />\\n <br />\\n <div class=\'terms-section\'>   <strong>Price, Promotion, Processing: </strong> Pricing, delivery date and other errors may be withdrawn or revised and/or your order may be cancelled at any time, without prior notice, before we have both (a) shipped or provided access to your product or service, and (b) received your payment for the product or service. All sales on <a href=\\"https://samsung.com\\" target=\\"_blank\\">Samsung.com</a> are subject to the full <a href=\\"https://www.samsung.com/us/business/shop/terms-and-conditions/\\" tar>Terms of Sale</a>. Samsung is not responsible for any errors, omissions or misdirected or lost orders, or orders which may be delayed. Samsung reserves the right to modify pricing and modify or cancel promotions at any time, without prior notice. </div> <span class=\'read-more-link\'>Show More</span> <br />\\n <br />\\n <div class=\'terms-section\'>  <sup>1</sup>QLED screens can produce 100% Color Volume in the DCI-P3 color space, the format for most cinema screens and HDR movies for television. </div> <br />\\n <br />\\n <div class=\'terms-section\'>  <sup>2</sup>Universal Stylus (USI) pen is a separate accessory, not included. Find out more about the universal stylus initiative at <a style=\'color: #0077c8;\' href=\'https://universalstylus.org\' target=\'_blank\'>universalstylus.org</a>. </div> <br />\\n <br />\\n <div class=\'terms-section\'>  <sup>3</sup>Chromebook software updates generally arrive every six weeks but are occasionally delayed to ensure optimal user experience upon rollout. </div> <br />\\n <br />\\n <div class=\'terms-section\'>  <sup>4</sup>Use of this feature requires you to have an agreement with a UEM provider. </div> <br />\\n <br />\\n <div class=\'terms-section\'>  <sup>5</sup>Chrome Enterprise license is available for an additional fee. </div> <br />\\n <br />\\n</div>"\n          },\n          "galaxy-xcover": {\n            "generalTerms": "<div> <div class=\'terms-section\'>  © 2021 Samsung Electronics America, Inc. ...

# %%
"Which capacities are available in the S23 Ultra?
# Out:
# Object `Ultra` not found.

# %%
index.query("What storage capacities are available on the S23 Ultra?")
# Out:
# INFO:root:> [query] Total LLM token usage: 3838 tokens
# INFO:root:> [query] Total embedding token usage: 11 tokens
# Response(response='\nThe storage capacities available on the S23 Ultra are not specified in the provided context information or in the Terms of Sale.', source_nodes=[SourceNode(source_text='notice. </div> <span class=\'read-more-link\'>Show More</span> <br />\\n <br />\\n <div class=\'terms-section\'>  <sup>1</sup>QLED screens can produce 100% Color Volume in the DCI-P3 color space, the format for most cinema screens and HDR movies for television. </div> <br />\\n <br />\\n <div class=\'terms-section\'>  <sup>2</sup>Universal Stylus (USI) pen is a separate accessory, not included. Find out more about the universal stylus initiative at <a style=\'color: #0077c8;\' href=\'https://universalstylus.org\' target=\'_blank\'>universalstylus.org</a>. </div> <br />\\n <br />\\n <div class=\'terms-section\'>  <sup>3</sup>Chromebook software updates generally arrive every six weeks but are occasionally delayed to ensure optimal user experience upon rollout. </div> <br />\\n <br />\\n <div class=\'terms-section\'>  <sup>4</sup>Use of this feature requires you to have an agreement with a UEM provider. </div> <br />\\n <br />\\n <div class=\'terms-section\'>  <sup>5</sup>Chrome Enterprise license is available for an additional fee. </div> <br />\\n <br />\\n</div>"\n          },\n          "chromebook2": {\n            "generalTerms": "<div> <div class=\'terms-section\'>  © 2021 Samsung Electronics America, Inc. All rights reserved. Samsung is a registered trademark of Samsung Electronics Co., Ltd. All products, logos and brand names are trademarks or registered trademarks of their respective companies. Screen images simulated. </div> <span class=\'read-more-link\'>Show More</span> <br />\\n <br />\\n <div class=\'terms-section\'>   <strong>Price, Promotion, Processing: </strong> Pricing, delivery date and other errors may be withdrawn or revised and/or your order may be cancelled at any time, without prior notice, before we have both (a) shipped or provided access to your product or service, and (b) received your payment for the product or service. All sales on <a href=\\"https://samsung.com\\" target=\\"_blank\\">Samsung.com</a> are subject to the full <a href=\\"https://www.samsung.com/us/business/shop/terms-and-conditions/\\" tar>Terms of Sale</a>. Samsung is not responsible for any errors, omissions or misdirected or lost orders, or orders which may be delayed. Samsung reserves the right to modify pricing and modify or cancel promotions at any time, without prior notice. </div> <span class=\'read-more-link\'>Show More</span> <br />\\n <br />\\n <div class=\'terms-section\'>  <sup>1</sup>QLED screens can produce 100% Color Volume in the DCI-P3 color space, the format for most cinema screens and HDR movies for television. </div> <br />\\n <br />\\n <div class=\'terms-section\'>  <sup>2</sup>Universal Stylus (USI) pen is a separate accessory, not included. Find out more about the universal stylus initiative at <a style=\'color: #0077c8;\' href=\'https://universalstylus.org\' target=\'_blank\'>universalstylus.org</a>. </div> <br />\\n <br />\\n <div class=\'terms-section\'>  <sup>3</sup>Chromebook software updates generally arrive every six weeks but are occasionally delayed to ensure optimal user experience upon rollout. </div> <br />\\n <br />\\n <div class=\'terms-section\'>  <sup>4</sup>Use of this feature requires you to have an agreement with a UEM provider. </div> <br />\\n <br />\\n <div class=\'terms-section\'>  <sup>5</sup>Chrome Enterprise license is available for an additional fee. </div> <br />\\n <br />\\n</div>"\n          },\n          "galaxy-xcover": {\n            "generalTerms": "<div> <div class=\'terms-section\'>  © 2021 Samsung Electronics America, Inc. All rights reserved. Samsung is a registered trademark of Samsung Electronics Co., Ltd. All products, logos and brand names are trademarks or registered trademarks of their respective companies. Screen images simulated. </div> <span class=\'read-more-link\'>Show More</ ...

# %%
response2.source_nodes
# Out:
# [SourceNode(source_text='unless specifically provided for in the terms and conditions of such offers. Additional terms, including terms that govern the resolution of disputes, apply. Click here to <a style=\'color: #0077c8;\' data-url=\'https://www.samsung.com/us/trade-in/terms-and-conditions/\' href=\'https://www.samsung.com/us/trade-in/terms-and-conditions/ \'  target=\'_blank\'>learn more</a></p>\\n </div> <span class=\'read-more-link\'>Show More</span> <br /> <br /> <div class=\'terms-section\'> <sup>φ</sup>Limited time only, while supplies last, exclusively on Samsung.com and the Shop Samsung App (excluding in-person Samsung Studios transactions made using the App). You must opt-in to the Samsung Upgrade Program, apply and be approved for a financing account (“Financing Account”) under the Samsung Financing Program, make an initial purchase of an eligible Samsung Galaxy device (“Initial Device”) on a 24 month payment plan using your Financing Account on standard financing terms or a separate required financing offer.\\n </div> <span class=\'read-more-link\'>Show More</span> <br /><br />\\n <div class=\'terms-section\'> *Please note that only your S20 will be eligible for the Upgrade Program.  The other items you selected will not be eligible for Upgrade and will be subject to 24 month Samsung Financing. </div> <br/> \\n <div class=\'terms-section\'>Verizon customers only: The Galaxy S20 5G is not compatible with Verizon’s current wideband 5G network but will work with Verizon’s 4G LTE service. Please consider the Verizon-compatible S20+ 5G or S20 Ultra 5G.</div></div> @disclaimer@ <br />\\n"\n        },\n        "galaxy-s20-fe": {\n          "generalTerms": "<div class=\'terms-section\'><sup>⊕</sup><strong> 0% APR for 24, 36 and 48 Months with Equal Payments:</strong> Available on purchases of select products charged to a Samsung Financing account. Minimum purchase: $49 for 24 months on phones, mobile accessories, tablets, PCs, and wearables; $299.99 for 36 months on phones, mobile accessories, tablets, PCs and wearables; $499.99 for 36 months on TVs; $649.99 for 48 months on PCs and $999.99 for 48 months on TVs. 0% APR from date of eligible purchase until paid in full. Monthly payment equals the eligible purchase amount multiplied by a repayment factor and rounded to the nearest penny (repayment factors: .04167 for 24 month, .02778 for 36 month, .02083 for 48 month). Last payment may vary due to rounding. Total amount of payments will not exceed eligible purchase amount. Other transactions and fees affect overall minimum payment amount. Advertised payment amount excludes taxes, delivery or other charges. Limited time offer. Regular account terms apply to non-promo purchases. Minimum interest charge: $1. Standard Purchase APR: 29.99%. Prior purchases excluded. Account must be in good standing. Subject to credit approval. Samsung Financing account issued by TD Bank, N.A\\n </div><span class=\'read-more-link\'>Show More</span> <br />\\n <br />\\n<div class=\'terms-section\'><sup>†</sup><strong> No Interest if Paid in Full within 6, 12, 18 or 24 Months:</strong> Available on purchases of select products charged to a Samsung Financing account. On purchases of $49 to $499.99 for 6-month and $500 or more for 12-month, 18-month, or 24-month. To avoid interest, you must pay the full promo balance before the promo period ends. If you do not, you will be charged interest from the purchase date at the standard Purchase APR. After the promo period ends, the standard APR also applies to the remaining balance and the charged interest. You are required to make minimum payments, but minimum payments will not pay off the balance on time. You must make larger payments to avoid the interest. Advertised monthly payment, if any, is greater than your required minimum monthly payment and excludes taxes, delivery or other charges. Limited Time Offer. Regular account terms apply to non-promo purchases. Minimum interest charge: $1. Standard Purcha ...

# %%
response = index.query("What are the carriers, the relevant field is carrierNames?")
# Out:
# INFO:root:> [query] Total LLM token usage: 4078 tokens
# INFO:root:> [query] Total embedding token usage: 12 tokens

# %%
response.source_nodes[0].source_text
# Out:
# '  "ordering": 2,\n          "minimumAmount": -1,\n          "defaultCarrierOffer": true,\n          "priority": 2000\n        },\n        "priority": 2000,\n        "carrier-store": {\n          "ordering": 3,\n          "priority": 950,\n          "globalPriority": 950\n        },\n        "defaultFinanceName": "T-Mobile Financing",\n        "defaultSuperscript": "<sup>v</sup>",\n        "headerSuperScript": "<sup>Ȣ</sup>",\n        "diamondSummayText": "<span><strong>$1$</strong></span>",\n        "paymentText": "<div><strong>$1$/mo</strong> for $2$ mo at 0% APR; Total $0$$sup$</div>",\n        "genericHeaderText": "<span><strong>$1$</strong> for <strong>$2$</strong> mo at <strong>0%</strong> APR </br> <strong>$0$</strong> with $WithTradeinText$ carrier financing</span>",\n        "pcIncludedMessage": "@pcName : $pcPerMonth$/mo",\n        "pricingText": "<div>$1$/mo <br> for $2$ mo*</div>",\n        "legal": "<sup>v</sup> Must be 18+ & 50 US/DC res. While supplies last, limited time offer. Purchase any Verizon Galaxy Note9, Galaxy S9 or Galaxy S9+ on Samsung.com or Shop Samsung App using Verizon device payment purchase & activate your device and save $200 instantly. Promotional credit applied instantly; remaining balance of device to be paid after 24 months. 0% APR. May not be combinable with carrier or retailer rebates, offers and discounts. Taxes, shipping fees and other costs may apply. Additional terms apply. Promotion may be combined with other offers.",\n        "homePaymentCardText": "<div><span class=\'homePaymentPerMonth\'>$1$</span><span class=\'homePaymentMonth\'>/mo </span> </span><br> <span class=\'homePaymentMonths\'>for $2$ mos$sup$ $tradeinSuperScript$</span></div>",\n        "homePaymentDescription": "<div><span class=\'homePaymentPerMonth\'>$1$</span><span class=\'homePaymentMonth\'>/mo </span> </span> <br> <span class=\'homePaymentMonths\'>for $2$ mos</span></div>",\n        "tradeinSuperscript": "<sup>θ</sup>",\n        "groupId": "t-mobilefinancing",\n        "fromText": "<div class=\'homePaymentFrom\'>From</div>",\n        "groupName": "<div class=\'homePaymentTitle\'>T-Mobile Financing</div>",\n        "recurringText": "one time and recurring",\n        "minimumAmount": -1,\n        "defaultCarrierOffer": true\n      },\n      {\n        "financeId": 52,\n        "financeName": "Samsung Financing",\n        "paymentSKU": "UPGRADE-02",\n        "type": "supc",\n        "priority": 70,\n        "ordering": 20,\n        "financeDescription": "<b>$1$</b>/mo for <b>$2$</b> mo at <b>0%</b> APR<sup>&oplus;</sup>; <sbr><b>$0$</b> total<sup>&oplus;</sup><br/> Excludes taxes and shipping. Not eligible for Samsung Upgrade.",\n        "tradeinSuperscript": "<sup>θ</sup>",\n        "defaultFinanceName": "Samsung Financing",\n        "diamondSummayText": "<span><strong>$1$</strong></span>",\n        "headerText": "<span><strong>$1$</strong> for <strong>$2$</strong> mo at <strong>0%</strong> APR$sup$ </br> <strong>$0$</strong> with $financeName$</span>",\n        "paymentText": "<span>$1$/mo for $2$ mo at 0% APR;</span><span>&nbsp;Total $0$<sup>&oplus;</sup></span>",\n        "paymentDescription": "<ul><li>$0 down for qualified customers, excludes taxes and shipping</li><li>Not eligible for Samsung Upgrade</li></ul>",\n        "pricingText": "<div>$1$/mo <br> for $2$ mo*</div>",\n        "homePaymentCardText": "<div><span class=\'homePaymentPerMonth\'>$1$</span><span class=\'homePaymentMonth\'>/mo </span> </span><br> <span class=\'homePaymentMonths\'>for $2$ mos$sup$ $tradeinSuperScript$</span></div>",\n        "homePaymentDescription": "<div><span class=\'homePaymentPerMonth\'>$1$</span><span class=\'homePaymentMonth\'>/mo </span> </span> <br> <span class=\'homePaymentMonths\'>for $2$ mos</span></div>"\n      },\n      {\n        "financeId": 22,\n        "sponsorOrigin": "Samsung",\n        "paymentId": "EIP_Phone",\n        "showAddons": false,\n        "addAddonsPrice": true,\n        "defaultFinanceName": "Sams ...
